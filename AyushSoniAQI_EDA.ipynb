# %%
import pandas as pd
import numpy as np

city_day      = pd.read_csv('city_day.csv')
city_hour     = pd.read_csv('city_hour.csv')
station_day   = pd.read_csv('station_day.csv')
station_hour  = pd.read_csv('station_hour.csv')
stations      = pd.read_csv('stations.csv')

datasets = {'city_day' : city_day,'city_hour': city_hour,'station_day' : station_day,'station_hour': station_hour,'stations': stations}
for name, df in datasets.items():
    print(f"  {name} - {df.shape}")
# Out:
# /tmp/ipykernel_17222/950418704.py:7: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   station_hour  = pd.read_csv('station_hour.csv')
#   city_day - (29531, 16)
#   city_hour - (707875, 16)
#   station_day - (108035, 16)
#   station_hour - (2589083, 16)
#   stations - (230, 5)

# %% [markdown]
# #Data Visualization

# %%
for name, df in datasets.items():
    print(f"\n{name}:")
    print(df.dtypes.to_string())
# Out:
# city_day:
# City           object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
#
# city_hour:
# City           object
# Datetime       object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
#
# station_day:
# StationId      object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# ...

# %%
for name, df in datasets.items():
    print(f"\n{name}")
    display(df.head())
# Out:
# city_day
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN
# city_hour
#         City             Datetime  PM2.5  PM10    NO    NO2    NOx  NH3    CO  \
# 0  Ahmedabad  2015-01-01 01:00:00    NaN   NaN  1.00  40.01  36.37  NaN  1.00
# ...

# %%
for name, df in datasets.items():
    print(f"\n{name}")
    display(df.describe(include='all').round(2))
# Out:
# city_day
#              City        Date     PM2.5      PM10        NO       NO2  \
# count       29531       29531  24933.00  18391.00  25949.00  25946.00
# unique         26        2009       NaN       NaN       NaN       NaN
# top     Ahmedabad  2020-06-26       NaN       NaN       NaN       NaN
# freq         2009          26       NaN       NaN       NaN       NaN
# mean          NaN         NaN     67.45    118.13     17.57     28.56
# std           NaN         NaN     64.66     90.61     22.79     24.47
# min           NaN         NaN      0.04      0.01      0.02      0.01
# 25%           NaN         NaN     28.82     56.26      5.63     11.75
# 50%           NaN         NaN     48.57     95.68      9.89     21.69
# 75%           NaN         NaN     80.59    149.74     19.95     37.62
# max           NaN         NaN    949.99   1000.00    390.68    362.21
#
#              NOx       NH3        CO       SO2        O3   Benzene   Toluene  \
# ...

# %%
for name, df in datasets.items():
    missing = df.isnull().sum()
    missing_pct = (missing / len(df) * 100).round(2)
    missing_df = pd.DataFrame({
        'Count': missing,
        'Pct': missing_pct
    }).query('Count > 0').sort_values('Pct', ascending=False)
    print(f"\n{name}")
    display(missing_df)
# Out:
# city_day
#             Count    Pct
# Xylene      18109  61.32
# PM10        11140  37.72
# NH3         10328  34.97
# Toluene      8041  27.23
# Benzene      5623  19.04
# AQI          4681  15.85
# AQI_Bucket   4681  15.85
# PM2.5        4598  15.57
# NOx          4185  14.17
# O3           4022  13.62
# SO2          3854  13.05
# NO2          3585  12.14
# NO           3582  12.13
# CO           2059   6.97
# city_hour
#              Count    Pct
# Xylene      455829  64.39
# PM10        296737  41.92
# NH3         272542  38.50
# Toluene     220607  31.16
# Benzene     163646  23.12
# PM2.5       145088  20.50
# SO2         130373  18.42
# O3          129208  18.25
# AQI_Bucket  129080  18.23
# AQI         129080  18.23
# NOx         123224  17.41
# NO2         117122  16.55
# NO          116632  16.48
# CO           86517  12.22
# station_day
#             Count    Pct
# Xylene      85137  78.81
# NH3         48105  44.53
# PM10        42706  39.53
# Toluene     38702  35.82
# ...

# %%
for name, df in datasets.items():
    dupes = df.duplicated().sum()
    print(f"  {name} -> {dupes}")
# Out:
#   city_day -> 0
#   city_hour -> 0
#   station_day -> 0
#   station_hour -> 0
#   stations -> 0

# %%
print(f"\ncity_day : {city_day['City'].nunique()}")
print(f"city_day : {city_day['AQI_Bucket'].unique()}")
print(f"city_day : {city_day['Date'].min()} to {city_day['Date'].max()}")
print(f"\nstation_day : {station_day['StationId'].nunique()}")
print(f"station_day : {station_day['Date'].min()} to {station_day['Date'].max()}")
print(f"\nstations : {stations.shape[0]}")
print(f"stations : {stations['State'].nunique()}")
print(f"stations : {stations['Status'].unique()}")
# Out:
# city_day : 26
# city_day : [nan 'Poor' 'Very Poor' 'Severe' 'Moderate' 'Satisfactory' 'Good']
# city_day : 2015-01-01 to 2020-07-01
#
# station_day : 110
# station_day : 2015-01-01 to 2020-07-01
#
# stations : 230
# stations : 21
# stations : ['Active' nan 'Inactive']

# %%
for name, df in datasets.items():
    nulls = df.isnull().sum()
    print(f"Sum of null in each attribute in {name}")
    print(f" {name} -> {nulls}\n\n ")
# Out:
# Sum of null in each attribute in city_day
#  city_day -> City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64
#
#
# Sum of null in each attribute in city_hour
#  city_hour -> City               0
# Datetime           0
# PM2.5         145088
# PM10          296737
# NO            116632
# NO2           117122
# NOx           123224
# NH3           272542
# CO             86517
# SO2           130373
# O3            129208
# Benzene       163646
# Toluene       220607
# Xylene        455829
# AQI           129080
# AQI_Bucket    129080
# dtype: int64
#
#
# Sum of null in each attribute in station_day
#  station_day -> StationId         0
# Date              0
# ...

# %%
for name, df in datasets.items():
    nulls = df.isnull().mean()*100
    print(f"Mean of null in each attribute in {name}")
    print(f" {name} -> {nulls}\n\n ")
# Out:
# Mean of null in each attribute in city_day
#  city_day -> City           0.000000
# Date           0.000000
# PM2.5         15.570079
# PM10          37.723071
# NO            12.129626
# NO2           12.139785
# NOx           14.171549
# NH3           34.973418
# CO             6.972334
# SO2           13.050692
# O3            13.619586
# Benzene       19.041008
# Toluene       27.229014
# Xylene        61.322001
# AQI           15.851139
# AQI_Bucket    15.851139
# dtype: float64
#
#
# Mean of null in each attribute in city_hour
#  city_hour -> City           0.000000
# Datetime       0.000000
# PM2.5         20.496274
# PM10          41.919407
# NO            16.476355
# NO2           16.545577
# NOx           17.407593
# NH3           38.501430
# CO            12.222073
# SO2           18.417517
# O3            18.252940
# Benzene       23.117923
# Toluene       31.164683
# Xylene        64.393996
# AQI           18.234858
# AQI_Bucket    18.234858
# dtype: float64
#
#
# ...

# %%
for name, df in datasets.items():
    nulls = df.isnull().mean().mean()*100
    print("Mean of null in each dataframe overall")
    print(f" {name} -> {nulls}\n\n ")
# Out:
# Mean of null in each dataframe overall
#  city_day -> 18.727777589651552
#
#
# Mean of null in each dataframe overall
#  city_hour -> 22.211592795338163
#
#
# Mean of null in each dataframe overall
#  station_day -> 24.452318693016153
#
#
# Mean of null in each dataframe overall
#  station_hour -> 28.15787481513725
#
#
# Mean of null in each dataframe overall
#  stations -> 8.434782608695652

# %%
for name, df in datasets.items():
    nulls = df.duplicated().sum()
    print(f"Duplicate rows in {name}")
    print(f" {name} -> {nulls}\n\n ")
# Out:
# Duplicate rows in city_day
#  city_day -> 0
#
#
# Duplicate rows in city_hour
#  city_hour -> 0
#
#
# Duplicate rows in station_day
#  station_day -> 0
#
#
# Duplicate rows in station_hour
#  station_hour -> 0
#
#
# Duplicate rows in stations
#  stations -> 0

# %%
import seaborn as sns

# %%
sns.countplot(city_day['AQI_Bucket'])
# Out:
# <Axes: xlabel='count', ylabel='AQI_Bucket'>

# %%
sns.histplot(city_day['AQI'],kde=True)
# Out:
# <Axes: xlabel='AQI', ylabel='Count'>

# %%
subd1 = {'city_day' : city_day,'city_hour': city_hour,'station_day' : station_day,'station_hour': station_hour}
for name, df in subd1.items():
    nulls = df.groupby('AQI_Bucket')['AQI'].mean()
    print(f"Mean of AQI bucket wise in {name}")
    print(f" {name} -> {nulls}\n\n ")
# Out:
# Mean of AQI bucket wise in city_day
#  city_day -> AQI_Bucket
# Good             40.268456
# Moderate        136.671877
# Poor            245.663430
# Satisfactory     76.765686
# Severe          567.886398
# Very Poor       343.004279
# Name: AQI, dtype: float64
#
#
# Mean of AQI bucket wise in city_hour
#  city_hour -> AQI_Bucket
# Good             39.583331
# Moderate        137.270339
# Poor            244.636031
# Satisfactory     76.112034
# Severe          619.247378
# Very Poor       341.641650
# Name: AQI, dtype: float64
#
#
# Mean of AQI bucket wise in station_day
#  station_day -> AQI_Bucket
# Good             39.801270
# Moderate        138.930924
# Poor            247.661707
# Satisfactory     76.795439
# Severe          511.560015
# Very Poor       341.033838
# Name: AQI, dtype: float64
#
#
# Mean of AQI bucket wise in station_hour
#  station_hour -> AQI_Bucket
# Good             39.093621
# Moderate        138.181047
# Poor            246.144914
# ...

# %%
city_day.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
city_day['Date'] = pd.to_datetime(city_day['Date'])
sns.lineplot(x='Date',y='AQI',data=city_day)
plt.show()

# %%
cols = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
       'O3', 'Benzene', 'Toluene', 'Xylene']

fig, axes = plt.subplots(4, 3, figsize=(18, 20))
axes = axes.flatten() # Flatten the 4x3 array of axes for easy iteration

for i, col in enumerate(cols):
    sns.histplot(city_day[col], kde=True, ax=axes[i]) # Add kde for density estimation
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')

plt.tight_layout() # Adjust layout to prevent overlapping titles/labels
plt.show()

# %%
cols = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
       'O3', 'Benzene', 'Toluene', 'Xylene']

fig, axes = plt.subplots(4, 3, figsize=(18, 20))
axes = axes.flatten() # Flatten the 4x3 array of axes for easy iteration

for i, col in enumerate(cols):
    sns.boxplot(y=city_day[col], ax=axes[i]) # Plot boxplot on current axis
    axes[i].set_title(f'Box Plot of {col}')
    axes[i].set_ylabel(col) # Set y-axis label

plt.tight_layout() # Adjust layout to prevent overlapping titles/labels
plt.show()

# %%
cols = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
       'O3', 'Benzene', 'Toluene', 'Xylene']

print("Skewness for each pollutant in city_day:")
for col in cols:
    skewness_value = city_day[col].skew()
    print(f"{col}: {skewness_value:.2f}")
# Out:
# Skewness for each pollutant in city_day:
# PM2.5: 3.37
# PM10: 2.05
# NO: 3.88
# NO2: 2.46
# NOx: 2.57
# NH3: 4.08
# CO: 8.88
# SO2: 4.08
# O3: 1.33
# Benzene: 21.30
# Toluene: 11.67
# Xylene: 7.89

# %%
for col in cols:
    city_day[col] = np.log1p(city_day[col])

# %%
fig, axes = plt.subplots(4, 3, figsize=(18, 20))
axes = axes.flatten() # Flatten the 4x3 array of axes for easy iteration

for i, col in enumerate(cols):
    sns.histplot(city_day[col], kde=True, ax=axes[i]) # Add kde for density estimation
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')

plt.tight_layout() # Adjust layout to prevent overlapping titles/labels
plt.show()

# %%
citycopy = city_day.drop(['City','Date','AQI_Bucket'], axis = 1)

# %%
plt.figure(figsize=(12, 10)) # Set a good figure size for the heatmap
sns.heatmap(citycopy.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Pollutants and AQI')
plt.show()

# %% [markdown]
# PM2.5 and PM10 have strongest relationships with AQI which means that particulate matter is the primary driver of air pollution.
#
# Nitrogen based pollutants like NO, NO2, NOx also show significant positive impact.
#
# SO2 and NH3 also have moderate influence on AQI levels.
#
# O3,  Benzene, Toluene, and Xylene have less impact on AQI.
#
# AQI increases significantly when multiple pollutants increase simultaneously.

# %%
pd.crosstab(city_day['City'], city_day['AQI_Bucket'])
# Out:
# AQI_Bucket          Good  Moderate  Poor  Satisfactory  Severe  Very Poor
# City
# Ahmedabad              1       198   238            43     638        216
# Aizawl                83         0     0            28       0          0
# Amaravati            158       219    47           409       0          8
# Amritsar              84       448    67           473       7         47
# Bengaluru            115       630    36          1124       0          5
# Bhopal                 2       165    31            76       0          4
# Brajrajnagar          14       421   120           122       0         36
# Chandigarh            48        74    20           154       0          3
# Chennai               12       804   110           941       6         11
# Coimbatore            43        13     0           288       0          0
# Delhi                 21       519   542           158     239        520
# Ernakulam              0        49     0           104       0          0
# ...

# %%
sns.heatmap(pd.crosstab(city_day['City'], city_day['AQI_Bucket']))
# Out:
# <Axes: xlabel='AQI_Bucket', ylabel='City'>

# %%
plt.figure(figsize=(16,10))
sns.boxplot(x='City', y='AQI', data=city_day)
plt.xticks(rotation=90)
plt.show()

# %%
city_day.groupby('City').apply(lambda x: x.isnull().mean()*100)
# Out:
# /tmp/ipykernel_17222/508646413.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   city_day.groupby('City').apply(lambda x: x.isnull().mean()*100)
#                     City  Date      PM2.5        PM10         NO        NO2  \
# City
# Ahmedabad            0.0   0.0  31.259333   79.741165  30.313589  30.263813
# Aizawl               0.0   0.0   1.769912    0.884956   0.000000   0.000000
# Amaravati            0.0   0.0   6.203996    5.783386   5.783386   5.783386
# Amritsar             0.0   0.0  10.483210    5.159705   7.616708   3.603604
# Bengaluru            0.0   0.0   7.267297   17.919363   0.298656   0.298656
# Bhopal               0.0   0.0   3.114187    3.114187   3.114187   3.114187
# ...

# %%
sns.histplot(city_day['AQI'].dropna(), kde=True)
plt.title('Distribution of AQI')
plt.show()

# %% [markdown]
# #Feature Engineering

# %%
station_hour  = pd.read_csv('station_hour.csv')
station_hour.shape
# Out:
# /tmp/ipykernel_17222/3224535260.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   station_hour  = pd.read_csv('station_hour.csv')
# (2589083, 16)

# %%
stations.head()
# stations.shape
# Out:
#   StationId                                     StationName  \
# 0     AP001                  Secretariat, Amaravati - APPCB
# 1     AP002  Anand Kala Kshetram, Rajamahendravaram - APPCB
# 2     AP003                      Tirumala, Tirupati - APPCB
# 3     AP004                 PWD Grounds, Vijayawada - APPCB
# 4     AP005          GVM Corporation, Visakhapatnam - APPCB
#
#                 City           State  Status
# 0          Amaravati  Andhra Pradesh  Active
# 1  Rajamahendravaram  Andhra Pradesh     NaN
# 2           Tirupati  Andhra Pradesh     NaN
# 3         Vijayawada  Andhra Pradesh     NaN
# 4      Visakhapatnam  Andhra Pradesh  Active

# %%
station_hour.head()
station_hour.shape
# Out:
# (2589083, 16)

# %%
mergeddf = pd.merge(station_hour, stations, on='StationId', how='left')
mergeddf.head()
# Out:
#   StationId             Datetime  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 0     AP001  2017-11-24 17:00:00  60.50   98.00  2.35  30.80  18.25   8.50
# 1     AP001  2017-11-24 18:00:00  65.50  111.25  2.70  24.20  15.07   9.77
# 2     AP001  2017-11-24 19:00:00  80.00  132.00  2.10  25.18  15.15  12.02
# 3     AP001  2017-11-24 20:00:00  81.50  133.25  1.95  16.25  10.23  11.58
# 4     AP001  2017-11-24 21:00:00  75.25  116.00  1.43  17.48  10.43  12.03
#
#     CO    SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket  \
# 0  0.1  11.85  126.40      0.1     6.10    0.10  NaN        NaN
# 1  0.1  13.17  117.12      0.1     6.25    0.15  NaN        NaN
# 2  0.1  12.08   98.98      0.2     5.98    0.18  NaN        NaN
# 3  0.1  10.47  112.20      0.2     6.72    0.10  NaN        NaN
# 4  0.1   9.12  106.35      0.2     5.75    0.08  NaN        NaN
#
#                       StationName       City           State  Status
# ...

# %%
mergeddf.shape
# Out:
# (2589083, 20)

# %%
mergeddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589083 entries, 0 to 2589082
# Data columns (total 20 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   StationId    object
#  1   Datetime     object
#  2   PM2.5        float64
#  3   PM10         float64
#  4   NO           float64
#  5   NO2          float64
#  6   NOx          float64
#  7   NH3          float64
#  8   CO           float64
#  9   SO2          float64
#  10  O3           float64
#  11  Benzene      float64
#  12  Toluene      float64
#  13  Xylene       float64
#  14  AQI          float64
#  15  AQI_Bucket   object
#  16  StationName  object
#  17  City         object
#  18  State        object
#  19  Status       object
# dtypes: float64(13), object(7)
# memory usage: 395.1+ MB

# %%
mergeddf.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  1.941394e+06  1.469831e+06  2.035372e+06  2.060110e+06  2.098275e+06
# mean   8.086481e+01  1.584839e+02  2.278825e+01  3.523689e+01  4.055115e+01
# std    8.947618e+01  1.397883e+02  4.846146e+01  3.497508e+01  5.590894e+01
# min    1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02  0.000000e+00
# 25%    2.816000e+01  6.400000e+01  3.050000e+00  1.310000e+01  1.135000e+01
# 50%    5.259000e+01  1.162500e+02  7.150000e+00  2.479000e+01  2.286000e+01
# 75%    9.774000e+01  2.040000e+02  1.858000e+01  4.548000e+01  4.570000e+01
# max    1.000000e+03  1.000000e+03  5.000000e+02  4.999900e+02  5.000000e+02
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  1.352465e+06  2.089781e+06  1.846346e+06  1.863110e+06  1.727504e+06
# mean   2.870856e+01  1.502366e+00  1.211602e+01  3.806408e+01  3.305493e+00
# ...

# %%
mergeddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589083 entries, 0 to 2589082
# Data columns (total 20 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   StationId    object
#  1   Datetime     object
#  2   PM2.5        float64
#  3   PM10         float64
#  4   NO           float64
#  5   NO2          float64
#  6   NOx          float64
#  7   NH3          float64
#  8   CO           float64
#  9   SO2          float64
#  10  O3           float64
#  11  Benzene      float64
#  12  Toluene      float64
#  13  Xylene       float64
#  14  AQI          float64
#  15  AQI_Bucket   object
#  16  StationName  object
#  17  City         object
#  18  State        object
#  19  Status       object
# dtypes: float64(13), object(7)
# memory usage: 395.1+ MB

# %%
pollutants = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3',
       'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene']
print("zero values in each column")
for col in pollutants:
    print(f"{col} - {(mergeddf[col] == 0).sum()}")
# Out:
# zero values in each column
# PM2.5 - 0
# PM10 - 0
# NO - 0
# NO2 - 0
# NOx - 117924
# NH3 - 0
# CO - 181502
# SO2 - 0
# O3 - 0
# Benzene - 392342
# Toluene - 312987
# Xylene - 208359

# %%
mergeddf.dtypes
# Out:
# StationId       object
# Datetime        object
# PM2.5          float64
# PM10           float64
# NO             float64
# NO2            float64
# NOx            float64
# NH3            float64
# CO             float64
# SO2            float64
# O3             float64
# Benzene        float64
# Toluene        float64
# Xylene         float64
# AQI            float64
# AQI_Bucket      object
# StationName     object
# City            object
# State           object
# Status          object
# dtype: object

# %%
for col in pollutants:
    mergeddf[col] = mergeddf[col].replace(0, np.nan)

# %%
mergeddf.dtypes
# Out:
# StationId       object
# Datetime        object
# PM2.5          float64
# PM10           float64
# NO             float64
# NO2            float64
# NOx            float64
# NH3            float64
# CO             float64
# SO2            float64
# O3             float64
# Benzene        float64
# Toluene        float64
# Xylene         float64
# AQI            float64
# AQI_Bucket      object
# StationName     object
# City            object
# State           object
# Status          object
# dtype: object

# %%
for col in pollutants:
    print(f"{col} - Zero Values: {(mergeddf[col] == 0).sum()}")
# Out:
# PM2.5 - Zero Values: 0
# PM10 - Zero Values: 0
# NO - Zero Values: 0
# NO2 - Zero Values: 0
# NOx - Zero Values: 0
# NH3 - Zero Values: 0
# CO - Zero Values: 0
# SO2 - Zero Values: 0
# O3 - Zero Values: 0
# Benzene - Zero Values: 0
# Toluene - Zero Values: 0
# Xylene - Zero Values: 0

# %%
mergeddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589083 entries, 0 to 2589082
# Data columns (total 20 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   StationId    object
#  1   Datetime     object
#  2   PM2.5        float64
#  3   PM10         float64
#  4   NO           float64
#  5   NO2          float64
#  6   NOx          float64
#  7   NH3          float64
#  8   CO           float64
#  9   SO2          float64
#  10  O3           float64
#  11  Benzene      float64
#  12  Toluene      float64
#  13  Xylene       float64
#  14  AQI          float64
#  15  AQI_Bucket   object
#  16  StationName  object
#  17  City         object
#  18  State        object
#  19  Status       object
# dtypes: float64(13), object(7)
# memory usage: 395.1+ MB

# %% [markdown]
# Missing values

# %%
for col in pollutants:
    print(f"{col} - {mergeddf[col].isna().mean()*100:.2f}%")
# Out:
# PM2.5 - 25.02%
# PM10 - 43.23%
# NO - 21.39%
# NO2 - 20.43%
# NOx - 23.51%
# NH3 - 47.76%
# CO - 26.30%
# SO2 - 28.69%
# O3 - 28.04%
# Benzene - 48.43%
# Toluene - 52.35%
# Xylene - 88.20%

# %%
station_hour.shape
# Out:
# (2589083, 16)

# %%
mergeddf[mergeddf[['AQI','PM2.5','PM10']].isnull().all(axis=1)].shape
# Out:
# (495557, 20)

# %%
mergeddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589083 entries, 0 to 2589082
# Data columns (total 20 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   StationId    object
#  1   Datetime     object
#  2   PM2.5        float64
#  3   PM10         float64
#  4   NO           float64
#  5   NO2          float64
#  6   NOx          float64
#  7   NH3          float64
#  8   CO           float64
#  9   SO2          float64
#  10  O3           float64
#  11  Benzene      float64
#  12  Toluene      float64
#  13  Xylene       float64
#  14  AQI          float64
#  15  AQI_Bucket   object
#  16  StationName  object
#  17  City         object
#  18  State        object
#  19  Status       object
# dtypes: float64(13), object(7)
# memory usage: 395.1+ MB

# %%
mergeddf = mergeddf.dropna(subset=['AQI','PM2.5','PM10'],how='all')

# %%
mergeddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2093526 entries, 0 to 2589082
# Data columns (total 20 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   StationId    object
#  1   Datetime     object
#  2   PM2.5        float64
#  3   PM10         float64
#  4   NO           float64
#  5   NO2          float64
#  6   NOx          float64
#  7   NH3          float64
#  8   CO           float64
#  9   SO2          float64
#  10  O3           float64
#  11  Benzene      float64
#  12  Toluene      float64
#  13  Xylene       float64
#  14  AQI          float64
#  15  AQI_Bucket   object
#  16  StationName  object
#  17  City         object
#  18  State        object
#  19  Status       object
# dtypes: float64(13), object(7)
# memory usage: 335.4+ MB

# %%
mergeddf.shape
# Out:
# (2093526, 20)

# %%
print("Missing values percentage")
for col in pollutants:
    
    print(f"{col} : {mergeddf[col].isna().mean()*100:.2f}%")
# Out:
# Missing values percentage
# PM2.5 : 7.27%
# PM10 : 29.79%
# NO : 6.52%
# NO2 : 5.26%
# NOx : 9.93%
# NH3 : 36.87%
# CO : 11.41%
# SO2 : 14.99%
# O3 : 14.25%
# Benzene : 39.08%
# Toluene : 43.42%
# Xylene : 85.72%

# %%
mergeddf['AQI'].isna().mean()*100
# Out:
# np.float64(3.5649425896788483)

# %%
mergeddf = mergeddf.drop(columns=['Xylene'])
mergeddf.head()
# Out:
#   StationId             Datetime  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 0     AP001  2017-11-24 17:00:00  60.50   98.00  2.35  30.80  18.25   8.50
# 1     AP001  2017-11-24 18:00:00  65.50  111.25  2.70  24.20  15.07   9.77
# 2     AP001  2017-11-24 19:00:00  80.00  132.00  2.10  25.18  15.15  12.02
# 3     AP001  2017-11-24 20:00:00  81.50  133.25  1.95  16.25  10.23  11.58
# 4     AP001  2017-11-24 21:00:00  75.25  116.00  1.43  17.48  10.43  12.03
#
#     CO    SO2      O3  Benzene  Toluene  AQI AQI_Bucket  \
# 0  0.1  11.85  126.40      0.1     6.10  NaN        NaN
# 1  0.1  13.17  117.12      0.1     6.25  NaN        NaN
# 2  0.1  12.08   98.98      0.2     5.98  NaN        NaN
# 3  0.1  10.47  112.20      0.2     6.72  NaN        NaN
# 4  0.1   9.12  106.35      0.2     5.75  NaN        NaN
#
#                       StationName       City           State  Status
# 0  Secretariat, Amaravati - APPCB  Amaravati  Andhra Pradesh  Active
# ...

# %%
pollutants.remove('Xylene')
pollutants.append('AQI')
pollutants
# Out:
# ['PM2.5',
#  'PM10',
#  'NO',
#  'NO2',
#  'NOx',
#  'NH3',
#  'CO',
#  'SO2',
#  'O3',
#  'Benzene',
#  'Toluene',
#  'AQI']

# %%
mergeddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2093526 entries, 0 to 2589082
# Data columns (total 19 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   StationId    object
#  1   Datetime     object
#  2   PM2.5        float64
#  3   PM10         float64
#  4   NO           float64
#  5   NO2          float64
#  6   NOx          float64
#  7   NH3          float64
#  8   CO           float64
#  9   SO2          float64
#  10  O3           float64
#  11  Benzene      float64
#  12  Toluene      float64
#  13  AQI          float64
#  14  AQI_Bucket   object
#  15  StationName  object
#  16  City         object
#  17  State        object
#  18  Status       object
# dtypes: float64(12), object(7)
# memory usage: 319.4+ MB

# %%
mergeddf['Datetime'] = pd.to_datetime(mergeddf['Datetime'])

mergeddf = mergeddf.sort_values(['StationId','Datetime'])

mergeddf = mergeddf.set_index('Datetime')

for col in pollutants:
    mergeddf[col] = mergeddf.groupby('StationId')[col].transform(
        lambda x: x.interpolate(method='time')
    )

mergeddf.reset_index(inplace=True)

# %%
mergeddf[pollutants].isnull().mean()* 100
# Out:
# PM2.5       2.998482
# PM10       26.439748
# NO          0.781170
# NO2         0.012037
# NOx         2.041580
# NH3        32.884330
# CO          0.675750
# SO2         9.282426
# O3          9.337596
# Benzene    17.749051
# Toluene    23.483874
# AQI         0.339762
# dtype: float64

# %%
mergeddf[pollutants].isnull().mean().mean()* 100
# Out:
# np.float64(10.502150439020102)

# %%
# Used forward and back fill as more dropping can reduce data and some have significant missind values so it will help
for col in pollutants:
    mergeddf[col] = mergeddf.groupby('StationId')[col].transform(lambda x: x.ffill().bfill())

# %%
mergeddf[pollutants].isnull().mean().mean()* 100
# Out:
# np.float64(9.72155747448722)

# %%
mergeddf['Hour'] = mergeddf['Datetime'].dt.hour

# %%
mergeddf[pollutants] = mergeddf.groupby(['StationId','Hour'])[pollutants].transform(lambda x: x.fillna(x.median()))

# %%
mergeddf[pollutants].isnull().mean().mean()* 100
# Out:
# np.float64(9.72155747448722)

# %%
mergeddf[pollutants] = mergeddf.groupby('StationId')[pollutants].transform(lambda x: x.fillna(x.median()))

# %%
mergeddf[pollutants].isnull().mean().mean()* 100
# Out:
# np.float64(9.72155747448722)

# %%
mergeddf[pollutants] = mergeddf[pollutants].fillna(mergeddf[pollutants].median())

# %%
mergeddf[pollutants].isnull().mean()* 100
# Out:
# PM2.5      0.0
# PM10       0.0
# NO         0.0
# NO2        0.0
# NOx        0.0
# NH3        0.0
# CO         0.0
# SO2        0.0
# O3         0.0
# Benzene    0.0
# Toluene    0.0
# AQI        0.0
# dtype: float64

# %%
mergeddf.shape
# Out:
# (2093526, 20)

# %%
mergeddf.isnull().sum()
# Out:
# Datetime           0
# StationId          0
# PM2.5              0
# PM10               0
# NO                 0
# NO2                0
# NOx                0
# NH3                0
# CO                 0
# SO2                0
# O3                 0
# Benzene            0
# Toluene            0
# AQI                0
# AQI_Bucket     74633
# StationName        0
# City               0
# State              0
# Status          7396
# Hour               0
# dtype: int64

# %%
bins = [0, 50, 100, 200, 300, 400, float('inf')]

labels = ['Good','Satisfactory','Moderate','Poor','Very Poor','Severe']

mergeddf['AQI_Bucket'] = mergeddf['AQI_Bucket'].fillna(pd.cut(mergeddf['AQI'], bins=bins, labels=labels))

# %%
pd.crosstab(pd.cut(mergeddf['AQI'], bins=bins, labels=labels),mergeddf['AQI_Bucket'])
# Out:
# AQI_Bucket      Good  Moderate    Poor  Satisfactory  Severe  Very Poor
# AQI
# Good          157809         0       0             0       0          0
# Satisfactory       0         0       0        549435       0          0
# Moderate           0    697580       0             0       0          0
# Poor               0         0  248371             0       0          0
# Very Poor          0         0       0             0       0     315542
# Severe             0         0       0             0  124789          0

# %%
mergeddf.isnull().sum()
# Out:
# Datetime          0
# StationId         0
# PM2.5             0
# PM10              0
# NO                0
# NO2               0
# NOx               0
# NH3               0
# CO                0
# SO2               0
# O3                0
# Benzene           0
# Toluene           0
# AQI               0
# AQI_Bucket        0
# StationName       0
# City              0
# State             0
# Status         7396
# Hour              0
# dtype: int64

# %%
fig , ax = plt.subplots(4,3,figsize=(15,15))
for i , col in enumerate(pollutants):
    rows = i // 3
    cols = i % 3
    sns.boxplot(mergeddf[col],ax=ax[rows,cols])
    ax[rows,cols].set_title(f"AQI vs {col}")

plt.tight_layout()
plt.show()

# %%
for col in pollutants:

    Q1 = mergeddf[col].quantile(0.25)
    Q3 = mergeddf[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    mergeddf[col] = mergeddf[col].clip(lower, upper)

# %%
fig , ax = plt.subplots(4,3,figsize=(15,15))
for i , col in enumerate(pollutants):
    rows = i // 3
    cols = i % 3
    sns.boxplot(mergeddf[col],ax=ax[rows,cols])
    ax[rows,cols].set_title(f"AQI vs {col}")

plt.tight_layout()
plt.show()

# %%
mergeddf[pollutants].skew()
# Out:
# PM2.5      1.056855
# PM10       0.796828
# NO         1.161603
# NO2        1.048914
# NOx        1.097468
# NH3        0.523945
# CO         0.975820
# SO2        0.998203
# O3         1.059241
# Benzene    1.158379
# Toluene    1.145385
# AQI        1.005021
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method='yeo-johnson')

mergeddf[pollutants] = pt.fit_transform(mergeddf[pollutants])

# %%
mergeddf[pollutants].skew()
# Out:
# PM2.5     -0.029236
# PM10      -0.015781
# NO         0.019596
# NO2       -0.034247
# NOx       -0.022373
# NH3       -0.041789
# CO         0.047353
# SO2       -0.028169
# O3        -0.048113
# Benzene    0.074102
# Toluene    0.009338
# AQI       -0.008933
# dtype: float64

# %%
mergeddf.State.unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Delhi',
#        'Gujarat', 'Haryana', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Maharashtra', 'Meghalaya', 'Madhya Pradesh', 'Mizoram', 'Odisha',
#        'Punjab', 'Rajasthan', 'Telangana', 'Tamil Nadu', 'Uttar Pradesh',
#        'West Bengal'], dtype=object)

# %%
len(mergeddf.State.unique())
# Out:
# 21

# %%
len(mergeddf.City.unique())
# Out:
# 26

# %%
pollutants.remove('AQI')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import TargetEncoder

# %%
processor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), pollutants),

        ('bucket',
         OrdinalEncoder(categories=[[
             'Good','Satisfactory','Moderate','Poor','Very Poor','Severe'
         ]]),
         ['AQI_Bucket']
        ),

        ('target', TargetEncoder(), ['City','State'])
    ],
    remainder='passthrough'
)

# %%
X = mergeddf.drop(columns=['AQI'])
y = mergeddf['AQI']
X.head()
# Out:
#              Datetime StationId     PM2.5      PM10        NO       NO2  \
# 0 2017-11-24 17:00:00     AP001  0.123333 -0.303385 -0.961806  0.228556
# 1 2017-11-24 18:00:00     AP001  0.217922 -0.110983 -0.856911 -0.052772
# 2 2017-11-24 19:00:00     AP001  0.463874  0.165542 -1.044106 -0.007731
# 3 2017-11-24 20:00:00     AP001  0.487294  0.181375 -1.096936 -0.477969
# 4 2017-11-24 21:00:00     AP001  0.387399 -0.045231 -1.304993 -0.403628
#
#         NOx       NH3        CO       SO2        O3   Benzene   Toluene  \
# 0 -0.387987 -1.269752 -1.903585  0.486248  1.734912 -1.509631  0.237477
# 1 -0.584675 -1.132003 -1.903585  0.633124  1.734912 -1.509631  0.258970
# 2 -0.579338 -0.902916 -1.903585  0.512668  1.734912 -1.325514  0.219942
# 3 -0.959201 -0.946392 -1.903585  0.319412  1.734912 -1.325514  0.323462
# 4 -0.941233 -0.901935 -1.903585  0.140156  1.734912 -1.325514  0.185448
#
#   AQI_Bucket                     StationName       City           State  \
# ...

# %%
X_processed = processor.fit_transform(X, y)

# %%
df = pd.DataFrame(X_processed,index=X.index,columns=processor.get_feature_names_out())
df.head()
# Out:
#   num__PM2.5 num__PM10   num__NO  num__NO2  num__NOx  num__NH3   num__CO  \
# 0   0.123333 -0.303385 -0.961806  0.228556 -0.387987 -1.269752 -1.903585
# 1   0.217922 -0.110983 -0.856911 -0.052772 -0.584675 -1.132003 -1.903585
# 2   0.463874  0.165542 -1.044106 -0.007731 -0.579338 -0.902916 -1.903585
# 3   0.487294  0.181375 -1.096936 -0.477969 -0.959201 -0.946392 -1.903585
# 4   0.387399 -0.045231 -1.304993 -0.403628 -0.941233 -0.901935 -1.903585
#
#    num__SO2   num__O3 num__Benzene num__Toluene bucket__AQI_Bucket  \
# 0  0.486248  1.734912    -1.509631     0.237477                2.0
# 1  0.633124  1.734912    -1.509631      0.25897                2.0
# 2  0.512668  1.734912    -1.325514     0.219942                2.0
# 3  0.319412  1.734912    -1.325514     0.323462                2.0
# 4  0.140156  1.734912    -1.325514     0.185448                2.0
#
#   target__City target__State remainder__Datetime remainder__StationId  \
# ...

# %%
df.columns
# Out:
# Index(['num__PM2.5', 'num__PM10', 'num__NO', 'num__NO2', 'num__NOx',
#        'num__NH3', 'num__CO', 'num__SO2', 'num__O3', 'num__Benzene',
#        'num__Toluene', 'bucket__AQI_Bucket', 'target__City', 'target__State',
#        'remainder__Datetime', 'remainder__StationId', 'remainder__StationName',
#        'remainder__Status', 'remainder__Hour'],
#       dtype='object')

# %%
pollutants = ['num__PM2.5', 'num__PM10', 'num__NO', 'num__NO2', 'num__NOx',
       'num__NH3', 'num__CO', 'num__SO2', 'num__O3', 'num__Benzene',
       'num__Toluene', 'bucket__AQI_Bucket']

# %% [markdown]
# # feature consdtruction

# %%
df.columns = df.columns.str.replace('num__','')
df.columns = df.columns.str.replace('bucket__','')
df.columns = df.columns.str.replace('target__','')
df.columns = df.columns.str.replace('remainder__','')

# %%
df.columns
# Out:
# Index(['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'AQI_Bucket', 'City', 'State', 'Datetime',
#        'StationId', 'StationName', 'Status', 'Hour'],
#       dtype='object')

# %%
df['AQI'] = y
df['AQI']
